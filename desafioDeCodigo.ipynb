# %% [markdown]
# <a href="https://colab.research.google.com/github/Marcelo-hta/Desafio-de-codigo-DIO/blob/main/desafioDeCodigo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Carregando o arquivo
df = pd.read_csv("gastos_usuarios.csv")

users = [
    {
        "id_usuario": row["id_usuario"],
        "nome_usuario": row["nome_usuario"],
        "categoria_gasto": row["categoria_gasto"],
        "valor": row["valor"],
        "perfil_usuario": row["perfil_usuario"]
    }
    for index, row in df.iterrows()
]

print(users)
# Out:
# [{'id_usuario': 1, 'nome_usuario': 'Ana Souza', 'categoria_gasto': 'Aluguel', 'valor': '1.169,01', 'perfil_usuario': 'quer economizar'}, {'id_usuario': 2, 'nome_usuario': 'Carlos Lima', 'categoria_gasto': 'Saúde', 'valor': '1.261,49', 'perfil_usuario': 'quer investir'}, {'id_usuario': 3, 'nome_usuario': 'Mariana Alves', 'categoria_gasto': 'Compras', 'valor': '1.169,94', 'perfil_usuario': 'sem preocupações'}]

# %%
from google import genai
from google.genai import types

client = genai.Client(api_key="AIzaSyAQkesdGjgVzRV-EyQFnORxr8ZBRF4uNjM")

def gerador_analise_gastos(id_usuario, nome_usuario, categoria_gasto, valor, perfil_usuario):
    response = client.models.generate_content(
    model="gemini-2.5-flash",
    config=types.GenerateContentConfig(
        system_instruction="Você é um especialista em controle de gastos"),
    contents=f"Analise os gastos do {nome_usuario} de acordo com a categoria: {categoria_gasto}, valor: {valor} e perfil: {perfil_usuario}. (Máximo de 100 caracteres)"

)
    return response.text

# %%
for user in users:
    analise = gerador_analise_gastos(
        user["id_usuario"],
        user["nome_usuario"],
        user["categoria_gasto"],
        user["valor"],
        user["perfil_usuario"]
    )
    print(f"Análise para {user['nome_usuario']}: {analise}")
# Out:
# Análise para Ana Souza: Aluguel R$1169,01 é alto. Para economizar, veja opções mais baratas ou renegocie.
# Análise para Carlos Lima: Saúde R$1.261,49. Para quem quer investir, é alto. Otimize esses gastos para liberar fundos.
# Análise para Mariana Alves: R$1.169,94 em Compras é alto. Mesmo sem preocupações, indica falta de controle e atenção.
